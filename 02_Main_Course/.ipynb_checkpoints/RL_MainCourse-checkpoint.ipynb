# %% [markdown]
# ## 1. Importing Dependencies

# %%
import os
import gym 

#Algorithms
from stable_baselines3 import PPO 

#Vecotrized Environment (Multiple Environment)
from stable_baselines3.common.vec_env import DummyVecEnv #Vectorizing not used

#How the model is performing after certain number of episodes.
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Simulation vs Real World Environment
# Real world training of robot will cause wear and tear of the robot
# Training and Testing can be done in Simulation Env and application can be done in real world.![image.png](attachment:image.png)

# %% [markdown]
# ## 2. Loading the Environment

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)

episodes = 5
for episode in range(1, episodes+1): # looping through 5 episodes
    state = env.reset() #get the environment to the initial state
    done = False        #temp variables
    score = 0           #temp variables (Score counter for every episode.)
    
    while not done:
        env.render()    
        action = env.action_space.sample()  # Later to be replaced with the Trained Model
        debug_text = ''
        n_state, reward, done, info = env.step(action)
        debug_text = str((n_state, reward, done, info))
        print(debug_text)
        
        score+=reward
    print('\n------------> Episode:{} Score:{}\n\n\n'.format(episode, score))
env.close()
# Out:
# (array([-0.01640109,  0.16350435, -0.04649386, -0.31788521]), 1.0, False, {})
# (array([-0.013131  , -0.03092563, -0.05285156, -0.04021969]), 1.0, False, {})
# (array([-0.01374952,  0.16491281, -0.05365596, -0.34909829]), 1.0, False, {})
# (array([-0.01045126, -0.02940659, -0.06063792, -0.07380594]), 1.0, False, {})
# (array([-0.01103939,  0.16652989, -0.06211404, -0.38498712]), 1.0, False, {})
# (array([-0.00770879,  0.36247614, -0.06981378, -0.69658947]), 1.0, False, {})
# (array([-0.00045927,  0.16838825, -0.08374557, -0.42667542]), 1.0, False, {})
# (array([ 0.00290849, -0.02545389, -0.09227908, -0.16152365]), 1.0, False, {})
# (array([ 0.00239942,  0.17085966, -0.09550955, -0.48183266]), 1.0, False, {})
# (array([ 0.00581661,  0.3671908 , -0.10514621, -0.80302431]), 1.0, False, {})
# (array([ 0.01316043,  0.56358529, -0.12120669, -1.12684514]), 1.0, False, {})
# (array([ 0.02443213,  0.37024168, -0.1437436 , -0.87450502]), 1.0, False, {})
# (array([ 0.03183696,  0.17733571, -0.1612337 , -0.63024555]), 1.0, False, {})
# (array([ 0.03538368,  0.37429649, -0.17383861, -0.96905244]), 1.0, False, {})
# (array([ 0.04286961,  0.18188046, -0.19321966, -0.73563003]), 1.0, False, {})
# (array([ 0.04650722,  0.37907162, -0.20793226, -1.08236628]), 1.0, False, {})
# (array([ 0.05408865,  0.18720884, -0.22957958, -0.86146375]), 1.0, True, {})
#
# ------------> Episode:1 Score:17.0
#
#
#
# (array([-0.03820959,  0.17149411, -0.03583028, -0.32049618]), 1.0, False, {})
# (array([-0.03477971,  0.36710752, -0.0422402 , -0.62425982]), 1.0, False, {})
# (array([-0.02743756,  0.17259996, -0.0547254 , -0.34517365]), 1.0, False, {})
# (array([-0.02398556, -0.02170254, -0.06162887, -0.07023747]), 1.0, False, {})
# (array([-0.02441961,  0.17424634, -0.06303362, -0.38171021]), 1.0, False, {})
# (array([-0.02093468, -0.01992658, -0.07066783, -0.10954886]), 1.0, False, {})
# (array([-0.02133322, -0.21396847, -0.0728588 ,  0.16002844]), 1.0, False, {})
# (array([-0.02561258, -0.01788315, -0.06965823, -0.15472074]), 1.0, False, {})
# (array([-0.02597025, -0.21194217, -0.07275265,  0.11519888]), 1.0, False, {})
# (array([-0.03020909, -0.01585727, -0.07044867, -0.19952083]), 1.0, False, {})
# (array([-0.03052624, -0.2099046 , -0.07443909,  0.0701334 ]), 1.0, False, {})
# (array([-0.03472433, -0.40388478, -0.07303642,  0.33843299]), 1.0, False, {})
# (array([-0.04280202, -0.59789557, -0.06626776,  0.60721971]), 1.0, False, {})
# (array([-0.05475994, -0.79203145, -0.05412337,  0.87831591]), 1.0, False, {})
# (array([-0.07060056, -0.98637781, -0.03655705,  1.15350406]), 1.0, False, {})
# (array([-0.09032812, -1.18100437, -0.01348697,  1.43450347]), 1.0, False, {})
# (array([-0.11394821, -0.98571869,  0.0152031 ,  1.13763655]), 1.0, False, {})
# (array([-0.13366258, -0.79079884,  0.03795583,  0.8497601 ]), 1.0, False, {})
# (array([-0.14947856, -0.59621448,  0.05495104,  0.56925011]), 1.0, False, {})
# (array([-0.16140285, -0.79206233,  0.06633604,  0.87872594]), 1.0, False, {})
# (array([-0.17724409, -0.59790144,  0.08391056,  0.60761366]), 1.0, False, {})
# (array([-0.18920212, -0.79409012,  0.09606283,  0.92550203]), 1.0, False, {})
# (array([-0.20508393, -0.99036902,  0.11457287,  1.24676202]), 1.0, False, {})
# (array([-0.22489131, -1.18675859,  0.13950811,  1.57302577]), 1.0, False, {})
# (array([-0.24862648, -1.38324174,  0.17096863,  1.90576958]), 1.0, False, {})
# (array([-0.27629131, -1.19032997,  0.20908402,  1.67064103]), 1.0, False, {})
# (array([-0.30009791, -1.38717812,  0.24249684,  2.02050647]), 1.0, True, {})
#
# ------------> Episode:2 Score:27.0
#
#
#
# (array([-0.01266148,  0.18522095, -0.04184539, -0.27426057]), 1.0, False, {})
# (array([-0.00895706, -0.00927975, -0.04733061,  0.00493612]), 1.0, False, {})
# (array([-0.00914266,  0.18648792, -0.04723188, -0.30229652]), 1.0, False, {})
# (array([-0.0054129 ,  0.38225009, -0.05327781, -0.60949333]), 1.0, False, {})
# (array([ 0.0022321 ,  0.18791181, -0.06546768, -0.33405579]), 1.0, False, {})
# (array([ 0.00599034, -0.00622025, -0.0721488 , -0.06271527]), 1.0, False, {})
# (array([ 0.00586593,  0.189858  , -0.0734031 , -0.37726082]), 1.0, False, {})
# (array([ 0.00966309,  0.38594153, -0.08094832, -0.69215524]), 1.0, False, {})
# (array([ 0.01738192,  0.19203041, -0.09479142, -0.42601383]), 1.0, False, {})
# (array([ 0.02122253,  0.38835823, -0.1033117 , -0.74701045]), 1.0, False, {})
# (array([ 0.0289897 ,  0.19480188, -0.11825191, -0.4885436 ]), 1.0, False, {})
# (array([ 0.03288573,  0.3913763 , -0.12802278, -0.81603112]), 1.0, False, {})
# (array([ 0.04071326,  0.19821783, -0.1443434 , -0.56620051]), 1.0, False, {})
# (array([ 0.04467762,  0.00538429, -0.15566741, -0.322248  ]), 1.0, False, {})
# (array([ 0.0447853 ,  0.20234073, -0.16211237, -0.65969195]), 1.0, False, {})
# (array([ 0.04883212,  0.39930312, -0.17530621, -0.99871439]), 1.0, False, {})
# (array([ 0.05681818,  0.20690264, -0.1952805 , -0.76581344]), 1.0, False, {})
# (array([ 0.06095623,  0.01492851, -0.21059677, -0.54037371]), 1.0, True, {})
#
# ------------> Episode:3 Score:18.0
#
#
#
# (array([ 0.00502711,  0.20067742, -0.03628504, -0.29741414]), 1.0, False, {})
# (array([ 0.00904066,  0.006091  , -0.04223332, -0.01639209]), 1.0, False, {})
# (array([ 0.00916248, -0.18840063, -0.04256116,  0.26267231]), 1.0, False, {})
# (array([ 0.00539446,  0.00730219, -0.03730771, -0.04312528]), 1.0, False, {})
# (array([ 0.00554051, -0.18726548, -0.03817022,  0.2375572 ]), 1.0, False, {})
# (array([ 0.0017952 ,  0.00838041, -0.03341908, -0.06691719]), 1.0, False, {})
# (array([ 0.00196281, -0.18624686, -0.03475742,  0.21503734]), 1.0, False, {})
# (array([-0.00176213, -0.38085512, -0.03045667,  0.49655678]), 1.0, False, {})
# (array([-0.00937923, -0.57553466, -0.02052554,  0.77948779]), 1.0, False, {})
# (array([-0.02088993, -0.77036849, -0.00493578,  1.06564289]), 1.0, False, {})
# (array([-0.0362973 , -0.96542478,  0.01637708,  1.35677264]), 1.0, False, {})
# (array([-0.05560579, -1.16074831,  0.04351253,  1.6545333 ]), 1.0, False, {})
# (array([-0.07882076, -1.35635026,  0.0766032 ,  1.96044715]), 1.0, False, {})
# (array([-0.10594776, -1.55219564,  0.11581214,  2.27585305]), 1.0, False, {})
# (array([-0.13699167, -1.35832529,  0.1613292 ,  2.02096827]), 1.0, False, {})
# (array([-0.16415818, -1.55471018,  0.20174856,  2.3589457 ]), 1.0, False, {})
# (array([-0.19525238, -1.75098311,  0.24892748,  2.70629632]), 1.0, True, {})
#
# ------------> Episode:4 Score:17.0
#
#
#
# (array([-0.04207317, -0.17740017,  0.04802645,  0.33468165]), 1.0, False, {})
# (array([-0.04562118,  0.01700653,  0.05472008,  0.05752219]), 1.0, False, {})
# (array([-0.04528105, -0.17885557,  0.05587053,  0.36695528]), 1.0, False, {})
# (array([-0.04885816, -0.37472509,  0.06320963,  0.67671852]), 1.0, False, {})
# (array([-0.05635266, -0.57066572,  0.076744  ,  0.98861376]), 1.0, False, {})
# (array([-0.06776597, -0.76672655,  0.09651628,  1.30437997]), 1.0, False, {})
# (array([-0.0831005 , -0.57295191,  0.12260388,  1.04340253]), 1.0, False, {})
# (array([-0.09455954, -0.76946965,  0.14347193,  1.37192172]), 1.0, False, {})
# (array([-0.10994894, -0.57640343,  0.17091036,  1.12733405]), 1.0, False, {})
# (array([-0.121477  , -0.77330139,  0.19345704,  1.46838127]), 1.0, False, {})
# (array([-0.13694303, -0.58100085,  0.22282467,  1.24183363]), 1.0, True, {})
#
# ------------> Episode:5 Score:11.0

# %%
str((n_state, reward, done, info))
# Out:
# '(array([-0.13694303, -0.58100085,  0.22282467,  1.24183363]), 1.0, True, {})'

# %%
env.close()

# %% [markdown]
# ## 3. Understanding the Environment

# %%
""""
Description:
        A pole is attached by an un-actuated joint to a cart, which moves along
        a frictionless track. The pendulum starts upright, and the goal is to
        prevent it from falling over by increasing and reducing the cart's
        velocity.
    Source:
        This environment corresponds to the version of the cart-pole problem
        described by Barto, Sutton, and Anderson
    Observation:
        Type: Box(4)
        Num     Observation               Min                     Max
        0       Cart Position             -4.8                    4.8
        1       Cart Velocity             -Inf                    Inf
        2       Pole Angle                -0.418 rad (-24 deg)    0.418 rad (24 deg)
        3       Pole Angular Velocity     -Inf                    Inf
    Actions:
        Type: Discrete(2)
        Num   Action
        0     Push cart to the left
        1     Push cart to the right
        Note: The amount the velocity that is reduced or increased is not
        fixed; it depends on the angle the pole is pointing. This is because
        the center of gravity of the pole increases the amount of energy needed
        to move the cart underneath it
    Reward:
        Reward is 1 for every step taken, including the termination step
    Starting State:
        All observations are assigned a uniform random value in [-0.05..0.05]
    Episode Termination:
        Pole Angle is more than 12 degrees.
        Cart Position is more than 2.4 (center of the cart reaches the edge of
        the display).
        Episode length is greater than 200.
        Solved Requirements:
        Considered solved when the average return is greater than or equal to
        195.0 over 100 consecutive trials.
    """

#to reset the env 
print("# Reset Env : ")
print(env.reset())

#to check all the possibloe actions we can take
print("\n# Action Space")
print(env.action_space)          # Discrete(2) for cartpole we have Left and Right (2 Actions in action space)

print("\n# Action Space - Sample : ")
print(env.action_space.sample()) # Gives out random samples from the Action Space

#to check the observation space
print("\n# Observation Space : box(min , max , size , DType)")
print(env.observation_space)

#to run steps in the environment - we pass action space as an argument
print("\n# Step Environment : n_state, reward+1,0,-1 , done, info")
print(env.step(1))
# Out:
# # Reset Env :
# [-0.04465558 -0.03437141 -0.02342469 -0.04597767]
#
# # Action Space
# Discrete(2)
#
# # Action Space - Sample :
# 1
#
# # Observation Space : box(min , max , size , DType)
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)
#
# # Step Environment : n_state, reward+1,0,-1 , done, info
# (array([-0.04534301,  0.16107847, -0.02434424, -0.34595829]), 1.0, False, {})

# %% [markdown]
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html
#
# ![image.png](attachment:image.png)
#
#
#
# https://stable-baselines3.readthedocs.io/en/master/guide/algos.html
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# https://youtu.be/Mut_u40Sqz4?t=2862

# %% [markdown]
# ## 4. Training Model
# Creating a directory to save the logs(tensor board) and the models
#
# └───Training
# &emsp;&emsp;&emsp;├───Logs
# &emsp;&emsp;&emsp;└───Saved Models
#
# We will be using the PPO as the Algorithm for the Cart-pole
#
# ![image.png](attachment:image.png)

# %%
# Make your own directories first
log_path = os.path.join('Training' , 'Logs')
print(log_path)
# Out:
# Training\Logs

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy',env , verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=40000)
# Out:
# Using cuda device
# Logging to Training\Logs\PPO_7
# -----------------------------
# | time/              |      |
# |    fps             | 234  |
# |    iterations      | 1    |
# |    time_elapsed    | 8    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008770548 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000619   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 56.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 321         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011677767 |
# |    clip_fraction        | 0.0735      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0784      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 35.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 344         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009716564 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0282     |
# |    value_loss           | 46.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 359         |
# |    iterations           | 5           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007380639 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 64          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 6           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006196943 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.3        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00857    |
# |    value_loss           | 69.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 7            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0049533565 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.566       |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 74.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 8            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0070721665 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.629        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.8         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00562     |
# |    value_loss           | 48.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 9           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.003912311 |
# |    clip_fraction        | 0.0296      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.476       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 71.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 391          |
# |    iterations           | 10           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0061160214 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 72.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 394          |
# |    iterations           | 11           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0029339932 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.3         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 93.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 12           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0033603737 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.711        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.5         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 74.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 400         |
# |    iterations           | 13          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004935453 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.9        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 77.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 14           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0042289747 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.552       |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.8         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 113          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 405          |
# |    iterations           | 15           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0035998747 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 119          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 145          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 16          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004534375 |
# |    clip_fraction        | 0.0167      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 58.3        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00142    |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 17          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.003023116 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.6        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0019     |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 18           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0030768872 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | 0.454        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 124          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 19          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.002232908 |
# |    clip_fraction        | 0.00254     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.7        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000493   |
# |    value_loss           | 178         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 20           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0068263244 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | 0.46         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.2         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 142          |
# ------------------------------------------

# %%
# Help for the PPO Policy
#PPO??

# %% [markdown]
# ## 5. Saving Model
# Creating a directory to save the trained models.

# %%
PPO_path = os.path.join('Training' , 'Saved Models' , 'PPO Model Cartpole')
model.save(PPO_path)

# %%
#Deleting and Reloading the Model from File
del model
model = PPO.load(PPO_path , env)

# %% [markdown]
# ## 6. Evaluating Model
# How the model is performing after certain number of episodes.
# <code>from stable_baselines3.common.evaluation import evaluate_policy</code>
#
# There are some environment for them the best Score is capped For E.g. in Cartpole-v1 [Max Score is Capped 200]
# So, If the Score of **200** is achieved the Env is considered Solved

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
#evaluate_policy??
# Out:
# C:\Users\astik\.conda\envs\RL3\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (200.0, 0.0)

# %%
# Closing the Environment after the Evaluation
env.close()

# %% [markdown]
# ## 7. Testing Model

# %%
obs = env.reset()  # Model gets the Obs as Environment Observation
model.predict(obs) # Gives out the Output Action(0/1-Push cart to the left/right) and State(None)
# Out:
# (array([0], dtype=int64), None)

# %%
episodes = 5
for episode in range(1, episodes+1): # looping through 5 episodes
    obs = env.reset() #get the environment to the initial state
    done = False        #temp variables
    score = 0           #temp variables (Score counter for every episode.)
    
    while not done:
        env.render()    
        action , _ = model.predict(obs)  # Now to be replaced with the Trained Model
        debug_text = ''
        obs, reward, done, info = env.step(action)
        debug_text = str((obs, reward, done, info))
        #print(debug_text)
        
        score+=reward
    print('\n------------> Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# ------------> Episode:1 Score:[200.]
#
# ------------> Episode:2 Score:[200.]
#
# ------------> Episode:3 Score:[200.]
#
# ------------> Episode:4 Score:[200.]
#
# ------------> Episode:5 Score:[200.]

# %% [markdown]
# ## 8. Viewing logs in Tensorboard

# %%
import os
os.getcwd()
log_path = os.path.join('Training' , 'Logs')
print(log_path)
training_log_path = os.path.join(os.getcwd() , log_path , 'PPO_4')
print(training_log_path)
# Out:
# Training\Logs
# D:\Coursera_Udacity\03_Reinforcement_Learning\02_Main_Course\Training\Logs\PPO_4

# %%
# Run this in the CMD 
#!tensorboard --logdir={training_log_path}

# %% [markdown]
# # NOTE
# ## Core Metrics to look at :
# 1. Average Reward
# 2. Average Episode Length
#
# ## Training Strategies :
# 1. Train For Longer
# 2. Hyper-Parameter Tuning
# 3. Try Different Algorithm

# %% [markdown]
# ## 9. Adding callbacks to Training Stage

# %%
#Adding Evaluation Callbacks for Early Stopping and Saving Model
from stable_baselines3.common.callbacks import EvalCallback , StopTrainingOnRewardThreshold
import os
save_path = os.path.join(os.getcwd(),'Training' , 'Saved Models')
save_path
# Out:
# 'D:\\Coursera_Udacity\\03_Reinforcement_Learning\\02_Main_Course\\Training\\Saved Models'

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=2b00,verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best = stop_callback,
                             eval_freq = 10000,
                             best_model_save_path = save_path,
                             verbose = 1 )

# %%
model = PPO('MlpPolicy',env , verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=40000 , callback=eval_callback)
# Out:
# Using cuda device

# %% [markdown]
# ## 10. Changing Policies
#
#
# https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html#on-policy-algorithms
#
# **net_arch :** is shared between the Custom actor (pi) and value function (vf)
# For E.g. :
# Value network deeper than policy network, first layer shared:<code> net_arch=[128, dict(vf=[256, 256])]</code>
#
#           obs
#            |
#          <128>
# &emsp;&emsp;&emsp;/ &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; \\
# action&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<256>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;<256>
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;|
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;value

# %%
net_arch = [128,128]
model = PPO('MlpPolicy',env , verbose=1, tensorboard_log=log_path , policy_kwargs={'net_arch' :net_arch})
model.learn(total_timesteps=10000 , callback=eval_callback)

# %% [markdown]
# ## 11. Using an Alternate Algorithm
# here, DQN

# %%
import os
import gym 

#Algorithms
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy',env , verbose=1, tensorboard_log=log_path)
model.learn(total_timesteps=20000 , callback=eval_callback)
# Out:
# Using cuda device
# Logging to Training\Logs\DQN_2
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.953    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6993     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 98       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.913    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7996     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 184      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.868    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 8422     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 278      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.836    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 8212     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 345      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.784    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 8403     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 454      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.738    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 8361     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 552      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.692    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 8318     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 649      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.644    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 8331     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 750      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.61     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 8288     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 822      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.573    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 8209     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 898      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.525    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 8236     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.487    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 8226     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.446    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 8246     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1166     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.382    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 8317     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1301     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.345    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 8342     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.305    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8292     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1463     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.273    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8256     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.221    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8301     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1639     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.171    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8275     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1746     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.133    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8258     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0961   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8203     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0557   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8181     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1988     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 8147     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 8172     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2190     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 8203     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 8228     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2411     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 8239     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2480     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 8257     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 8253     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 8226     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2756     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 8236     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2883     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 8231     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2980     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 8215     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 8201     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 8183     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 8178     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 8206     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 8184     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3477     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 8179     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3565     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 8159     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3638     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 8168     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3740     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 8200     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 8184     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 8263     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4135     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 8271     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 8241     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4322     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 8260     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 8222     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4468     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 8208     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 8196     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 8179     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 8133     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 8146     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4814     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 8140     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 8115     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 8099     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4997     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 8113     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 8125     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 8129     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5268     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 8147     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5377     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 8143     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 8127     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5519     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 8114     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 8148     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5745     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 8149     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5827     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 8143     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 8138     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 8150     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6146     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 8140     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 8134     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 8146     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 8129     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6438     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 8137     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 8134     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 8126     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6695     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 8139     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 8129     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 8126     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 8144     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7069     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 8160     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7189     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 8152     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 8148     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 8126     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7419     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 8124     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7498     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 8114     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 8110     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 8109     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 8114     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 8105     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7887     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 8100     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 8084     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8037     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 8080     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8105     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 8069     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 8061     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 8069     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8393     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 8069     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 8058     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8555     |
# ----------------------------------
# Eval num_timesteps=8560, episode_reward=12.60 +/- 1.62
# Episode length: 12.60 +/- 1.62
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 12.6     |
# |    mean_reward      | 12.6     |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 8560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 7686     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 7672     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 7656     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8784     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 7653     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 8879     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 7683     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 7706     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9119     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 7709     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9222     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 7719     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 7735     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9439     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 7724     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 7729     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9664     |
# ----------------------------------
# C:\Users\astik\.conda\envs\RL3\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 7731     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 7738     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 7730     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 9912     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 7720     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 7719     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 7725     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 7738     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 7736     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 7755     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 7747     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 7750     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 7758     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 7766     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 7762     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 7773     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 7774     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11128    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 7794     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 7783     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 7794     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 7780     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 7776     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 7780     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 7780     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11767    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 7784     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 7767     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 7780     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 7769     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 7778     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 7761     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12297    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 7772     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 7770     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 7770     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12583    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 7769     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12666    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 7765     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 7758     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 7759     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 7762     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 7758     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13091    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 7765     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 7760     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 7758     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13331    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 7762     |
# |    time_elapsed     | 1        |
# ...
# |    fps              | 7811     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 7811     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 7807     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 7797     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 7791     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 7792     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 15994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 7789     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16090    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 7783     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 7783     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 7780     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16319    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 7780     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 7781     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 7787     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 7787     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16730    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 7785     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 7780     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16867    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 7789     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 16971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 7788     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17041    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 7792     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 7790     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 7795     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 7798     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 7807     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 7768     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17712    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 7766     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 7766     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 7769     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 17932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 7778     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 7781     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 7783     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18227    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 7780     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 7779     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 7780     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18477    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 7780     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18547    |
# ----------------------------------
# Eval num_timesteps=18560, episode_reward=13.20 +/- 1.47
# Episode length: 13.20 +/- 1.47
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 13.2     |
# |    mean_reward      | 13.2     |
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    total timesteps  | 18560    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 7570     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18634    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 7574     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18735    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 7579     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18832    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 7580     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 18917    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 7580     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19012    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 7590     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 7590     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 7593     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 7598     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19401    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 7599     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 7597     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 7600     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 7598     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 7598     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 7600     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 7606     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 19931    |
# ----------------------------------
